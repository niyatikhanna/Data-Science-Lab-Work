# %%
# =====================================
# Step 1: Import Libraries
# =====================================
import ______ as pd
import ______ as np
import seaborn as ______
import matplotlib.pyplot as ______

from sklearn.model_selection import ____________
from sklearn.preprocessing import ____________
from sklearn.svm import ____________
from sklearn.metrics import ____________

# =====================================
# Step 2: Load Dataset
# =====================================
data_df = pd.read_csv("____________________________")

# =====================================
# Step 3: Basic Data Exploration
# =====================================
print(data_df._______())      # first few rows
print(data_df._______())      # dataset info
print(data_df._______())      # statistical summary

# =====================================
# Step 4: Missing Values
# =====================================
print(data_df.________())

# =====================================
# Step 5: Class Distribution
# =====================================
print(data_df["__________"].value_counts())

# =====================================
# Step 6: Histogram Plot
# =====================================
data_df.hist(figsize=(__,__))
plt.________()

# =====================================
# Step 7: Correlation Heatmap
# =====================================
plt.figure(figsize=(__,__))

sns.________(
    data_df.________(),
    annot=______,
    cmap="________"
)

plt.title("________________________")
plt.show()

# =====================================
# Step 8: KDE Plot
# =====================================
plt.figure(figsize=(__,__))

sns.________(
    x = data_df["_______"],
    y = data_df["_______"],
    hue = data_df["____________"],
    fill = ______
)

plt.title("________________________")
plt.xlabel("________")
plt.ylabel("________")

plt.show()

# =====================================
# Step 9: Feature & Target Split
# =====================================
X = data_df.________("__________", axis=1)
y = data_df["__________"]

# =====================================
# Step 10: Train-Test Split
# =====================================
X_train, X_test, y_train, y_test = ____________(
    X, y, test_size=____, random_state=____
)

# =====================================
# Step 11: Feature Scaling
# =====================================
scaler = ____________()
X_train = scaler.__________(X_train)
X_test = scaler.__________(X_test)

# =====================================
# Step 12: Train SVM Model
# =====================================
model = ____________(kernel="______")
model.__________(X_train, y_train)

# =====================================
# Step 13: Prediction & Evaluation
# =====================================
y_pred = model.__________(X_test)

print("Accuracy:", ____________(y_test, y_pred))
